# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import copy

# %% [markdown]
# # Random Stock Correlation Analysis

# %%
df = pd.read_csv('./Correlation Results/random_stock_correlations.csv')

# %%
df_flipped = copy.deepcopy(df)
df_flipped.columns = ['stock2', 'stock1', 'Correlation']

# %%
new_df = pd.concat([df, df_flipped], axis = 0)

# %%
final_df = new_df.pivot(index='stock1', columns='stock2', values='Correlation')

# %%
final_df.fillna(1, inplace=True)

# %%
final_df
# Out:
# stock2       AXP       BBY       CAG       EMR       HSY      INCY       MCK  \
# stock1
# AXP     1.000000  0.243873 -0.201925  0.336721  0.337455  0.467742  0.009143
# BBY     0.243873  1.000000 -0.077021 -0.153700 -0.234420  0.341826  0.015063
# CAG    -0.201925 -0.077021  1.000000  0.512145  0.287846  1.000000  0.380230
# EMR     0.336721 -0.153700  0.512145  1.000000  0.068693  1.000000  0.050247
# HSY     0.337455 -0.234420  0.287846  0.068693  1.000000  0.977237  0.819813
# INCY    0.467742  0.341826  1.000000  1.000000  0.977237  1.000000  0.312716
# MCK     0.009143  0.015063  0.380230  0.050247  0.819813  0.312716  1.000000
# MNST   -0.004130  0.103556  0.560954 -0.239946 -0.401949  1.000000 -0.013791
# TGT     0.190230  0.574329 -0.078412  0.122893  0.034406 -0.016354 -0.053109
# WBA     0.330277  0.659111  0.890143  0.483977  1.000000  1.000000 -0.015973
#
# stock2      MNST       TGT       WBA
# stock1
# AXP    -0.004130  0.190230  0.330277
# BBY     0.103556  0.574329  0.659111
# CAG     0.560954 -0.078412  0.890143
# EMR    -0.239946  0.122893  0.483977
# HSY    -0.401949  0.034406  1.000000
# INCY    1.000000 -0.016354  1.000000
# MCK    -0.013791 -0.053109 -0.015973
# MNST    1.000000 -0.606003  1.000000
# TGT    -0.606003  1.000000  0.096782
# WBA     1.000000  0.096782  1.000000

# %%
plt.figure(figsize=(10,10))
heat_map = sns.heatmap( final_df, linewidth = 1 , annot = True)
plt.title( "Correlation Heatmap" )
plt.show()

# %%
means = final_df.mean().sort_values(ascending=False)

# %%
means.plot.bar();
plt.title('Average of each correlation')
plt.xlabel('Stock')
# Out:
# Text(0.5, 0, 'Stock')

# %% [markdown]
# ---

# %% [markdown]
# # Selected Stock Correlation Analysis

# %%
df2 = pd.read_csv('./Correlation Results/selected_stock_correlations.csv')

# %%
df_flipped2 = copy.deepcopy(df2)
df_flipped2.columns = ['stock2', 'stock1', 'Correlation']

# %%
new_df2 = pd.concat([df2, df_flipped2], axis = 0)

# %%
final_df2 = new_df2.pivot(index='stock1', columns='stock2', values='Correlation')

# %%
final_df2.fillna(1, inplace=True)

# %%
final_df2
# Out:
# stock2      AMGN      ATVI      COST      GILD      MDLZ       PEP      REGN  \
# stock1
# AMGN    1.000000  0.582112  0.054588  0.642329  1.000000  0.023357  0.809439
# ATVI    0.582112  1.000000 -0.552583  0.049441  0.677681  0.183715  0.376793
# COST    0.054588 -0.552583  1.000000  0.718866  0.313878  0.917087  0.855601
# GILD    0.642329  0.049441  0.718866  1.000000  1.000000  1.000000  1.000000
# MDLZ    1.000000  0.677681  0.313878  1.000000  1.000000  0.690919  0.523709
# PEP     0.023357  0.183715  0.917087  1.000000  0.690919  1.000000  0.667348
# REGN    0.809439  0.376793  0.855601  1.000000  0.523709  0.667348  1.000000
# VRTX    0.341546 -0.254492  1.000000  0.520242  1.000000  1.000000  0.869611
# WBA     0.670759  0.526604  0.682491  0.289954  1.000000  0.758100  0.948886
# XEL     1.000000  1.000000  0.073530  1.000000  0.480233  0.133738  0.849617
#
# stock2      VRTX       WBA       XEL
# stock1
# AMGN    0.341546  0.670759  1.000000
# ATVI   -0.254492  0.526604  1.000000
# COST    1.000000  0.682491  0.073530
# GILD    0.520242  0.289954  1.000000
# MDLZ    1.000000  1.000000  0.480233
# PEP     1.000000  0.758100  0.133738
# REGN    0.869611  0.948886  0.849617
# VRTX    1.000000  0.765816  1.000000
# WBA     0.765816  1.000000  1.000000
# XEL     1.000000  1.000000  1.000000

# %%
plt.figure(figsize=(10,10))
heat_map = sns.heatmap( final_df2, linewidth = 1 , annot = True)
plt.title( "Correlation Heatmap" )
plt.show()

# %%
means2 = final_df2.mean().sort_values(ascending=False)

# %%
means2
# Out:
# stock2
# REGN    0.790100
# MDLZ    0.768642
# WBA     0.764261
# XEL     0.753712
# VRTX    0.724272
# GILD    0.722083
# PEP     0.637426
# AMGN    0.612413
# COST    0.506346
# ATVI    0.358927
# dtype: float64

# %%
means2.plot.bar();
plt.title('Average of each correlations')
plt.xlabel('Stock')
# Out:
# Text(0.5, 0, 'Stock')

# %% [markdown]
# # Final Portfolio

# %% [markdown]
# We choose the top 5 correlated stock for both the randomly picked stocks and the selected stocks

# %%
top5_random = means.iloc[0:5]
top5_selected = means2.iloc[0:5]

# %%
top5_random
# Out:
# stock2
# INCY    0.708317
# WBA     0.644432
# CAG     0.427396
# HSY     0.388908
# EMR     0.318103
# dtype: float64

# %%
top5_selected
# Out:
# stock2
# REGN    0.790100
# MDLZ    0.768642
# WBA     0.764261
# XEL     0.753712
# VRTX    0.724272
# dtype: float64
